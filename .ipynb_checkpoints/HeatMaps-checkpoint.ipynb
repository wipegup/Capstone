# %%
import pickle
# %matplotlib inline
with open('df.pickle', 'rb') as f:
    df = pickle.load(f)
exec(open('./GroupingClasses.py').read())

# %% [markdown]
# showPlot is a general graphing function for creating heatmaps of sequenceRank v. dateRank data.
#
# It has several options:
# - source *unactivated*
# - kind : 'agg'(default) or 'unagg' 'agg' creates visualizations which aggregates all members of each (sequenceRank, dateRank) pair. 'unagg' gives a

# %%
showPlot(df, kind = 'agg', num = 'All', spgDiscard= [1,2],SDateVGDate= False, Epoch= [1750, 1900], func = 'count')
# Out:
# init opts [('SDate > GDate', False), ('Type', None), ('OrigG', None), ('SDate', [1750, 1900])]
#  Epoch 1750 to 1900  SDate > GDate
#  Epoch 1750 to 1900  Not SDate > GDate
